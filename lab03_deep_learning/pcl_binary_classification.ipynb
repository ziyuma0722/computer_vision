# %% [markdown]
# # Point Cloud Binary Classification with PyTorch

# %% [markdown]
# Make sure you are using the `dl4cv` conda environment.

# %% [markdown]
# ## Dataset loading and visualization

# %% [markdown]
# The input X contain 100 2D points, and y are their corresponding labels (0 or 1). The goal is to train a model that can classify every point to its correct label.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.optim import Adam

dataset = np.load('data/2d_pcl_dataset.npz')
X, y = dataset['X'], dataset['y']

X0 = X[y==0] # 50 2D points have label 0
X1 = X[y==1] # 50 2D points have label 1

def plot(X0, X1, fit_param=None):
    plt.scatter(X0[:,0], X0[:,1], color='red', label=0)
    plt.scatter(X1[:,0], X1[:,1], color='blue', label=1)

    plt.xlim([-0.55, 0.55])
    plt.ylim([-0.35, 0.25])
    plt.legend()
    plt.show()
    plt.clf()

plot(X0, X1)

# %% [markdown]
# ## Logistic Regression for the point cloud classification task

# %% [markdown]
# Starting by filling in the `Simple2DDataset` class below. First, in the class constructore `__init__`, you will need to read the right `2d_pcl_dataset.npz` from disk.
#
# Second, in the `__getitem__`, you will need to take a single data point and its label based on its index `idx`

# %%
class Simple2DDataset(Dataset):
    def __init__(self):
        super().__init__()
        #########################################################################
        # TODO: read data from disk using np.load.
        # Data is located in the folder "data".
        # Save samples and labels to class members self.X and self.y respectively.
        # samples should be an Nx2 numpy array. Labels should be Nx1.
        #########################################################################
        self.X = np.load('data/2d_pcl_dataset.npz')['X']
        self.y = np.load('data/2d_pcl_dataset.npz')['y']

    def __len__(self):
        # Returns the number of samples in the dataset.
        return self.X.shape[0]

    def __getitem__(self, idx):
        #########################################################################
        # TODO: return the sample and label with index idx
        #########################################################################
        point = self.X[idx]
        label = self.y[idx]

        # Convert to tensor.
        return torch.from_numpy(point).float(), \
               torch.from_numpy(label[np.newaxis]).float()

# %% [markdown]
# With the complete `Simple2DDataset`, we can create a PyTorch dataloader
#
# **NOTE**: if you encounter some unexpected errors in data loading, try setting `NUM_WORKERS = 0`

# %%
BATCH_SIZE = 8
NUM_WORKERS = 2

# create the dataloader
dataset = Simple2DDataset()
train_dataloader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    shuffle=True
)

# %% [markdown]
# Now, define your first network by filling in the `LinearClassifier` class below.
#
# Add a single linear layer `nn.Linear` inside the `nn.Sequential` call. The input is 2D, and the output should be a single value, corresponding to the probability of a given 2D point being part of cluster 0.

# %%
class LinearClassifier(nn.Module):
    def __init__(self):
        super().__init__()

        self.codename = 'linear'

        #########################################################################
        # TODO: add a single linear layer with nn.Linear, inside the `nn.Sequential` call.
        # Input is 2D.
        # Output is a single value.
        #########################################################################
        self.model = nn.Sequential(nn.Linear(2,1))

    def forward(self, batch):
        # Process batch using the defined model.
        x = self.model(batch)
        # Final sigmoid activation to obtain a probability between 0 and 1.
        return torch.sigmoid(x)

# %% [markdown]
# Now, you are asked to implement the training loop below

# %%
def train(net, optimizer, dataloader, epoch):
    net.train()
    loss_sum = 0
    for batch_idx, (point, label) in enumerate(dataloader):
        # First we need to zero the gradient, otherwise PyTorch would accumulate them
        optimizer.zero_grad()

        #########################################################################
        #TODO:
        # 1. forward pass of the network to obtain the predictions given the batch
        # 2. compute the loss using F.binary_cross_entropy
        # 3. backward pass on the loss using loss.backward(), and one step
        # of gradient descent (optimization) using optimizer.step()
        #########################################################################
        m_label = net(point)
        loss = F.binary_cross_entropy(m_label, label)
        loss.backward()
        optimizer.step()

        loss_sum += loss.item()
    return loss_sum

# %% [markdown]
# You can now run below to train the linear model.

# %%
NUM_EPOCHS = 100
# create the network.
net = LinearClassifier()

# create the optimizer.
optimizer = Adam(net.parameters(), lr=0.1)

best_accuracy = 0
for epoch_idx in range(NUM_EPOCHS):
    loss = train(net, optimizer, train_dataloader, epoch_idx)
    print('[Epoch %02d] Loss: %.4f' % (epoch_idx + 1, loss))
# Out:
# [Epoch 01] Loss: 8.0658
# [Epoch 02] Loss: 6.5382
# [Epoch 03] Loss: 5.5863
# [Epoch 04] Loss: 5.2302
# [Epoch 05] Loss: 4.7709
# [Epoch 06] Loss: 4.6075
# [Epoch 07] Loss: 4.3483
# [Epoch 08] Loss: 4.2839
# [Epoch 09] Loss: 4.1663
# [Epoch 10] Loss: 4.0631
# [Epoch 11] Loss: 4.0259
# [Epoch 12] Loss: 3.8596
# [Epoch 13] Loss: 3.8091
# [Epoch 14] Loss: 3.9494
# [Epoch 15] Loss: 3.8852
# [Epoch 16] Loss: 3.8666
# [Epoch 17] Loss: 3.6713
# [Epoch 18] Loss: 3.6737
# [Epoch 19] Loss: 3.6186
# [Epoch 20] Loss: 3.5836
# [Epoch 21] Loss: 3.7712
# [Epoch 22] Loss: 3.6728
# [Epoch 23] Loss: 3.6684
# [Epoch 24] Loss: 3.5169
# [Epoch 25] Loss: 3.5845
# [Epoch 26] Loss: 3.6075
# [Epoch 27] Loss: 3.7543
# [Epoch 28] Loss: 3.7603
# [Epoch 29] Loss: 3.5284
# [Epoch 30] Loss: 3.5140
# [Epoch 31] Loss: 3.4985
# [Epoch 32] Loss: 3.5343
# [Epoch 33] Loss: 3.4922
# [Epoch 34] Loss: 3.5216
# [Epoch 35] Loss: 3.4771
# [Epoch 36] Loss: 3.5543
# [Epoch 37] Loss: 3.5052
# [Epoch 38] Loss: 3.4528
# [Epoch 39] Loss: 3.8996
# [Epoch 40] Loss: 3.6821
# [Epoch 41] Loss: 3.4662
# [Epoch 42] Loss: 3.5854
# [Epoch 43] Loss: 3.4698
# [Epoch 44] Loss: 3.7272
# [Epoch 45] Loss: 3.5795
# [Epoch 46] Loss: 3.5107
# [Epoch 47] Loss: 3.4458
# [Epoch 48] Loss: 3.5227
# [Epoch 49] Loss: 3.4426
# [Epoch 50] Loss: 3.4501
# [Epoch 51] Loss: 3.6026
# [Epoch 52] Loss: 3.5184
# [Epoch 53] Loss: 3.4748
# [Epoch 54] Loss: 3.7133
# [Epoch 55] Loss: 3.6571
# [Epoch 56] Loss: 3.7153
# [Epoch 57] Loss: 3.6510
# [Epoch 58] Loss: 3.5044
# [Epoch 59] Loss: 3.4819
# [Epoch 60] Loss: 3.4938
# [Epoch 61] Loss: 3.4805
# [Epoch 62] Loss: 3.4448
# [Epoch 63] Loss: 3.8094
# [Epoch 64] Loss: 3.4415
# [Epoch 65] Loss: 3.5975
# [Epoch 66] Loss: 3.4337
# [Epoch 67] Loss: 3.7076
# [Epoch 68] Loss: 3.4693
# [Epoch 69] Loss: 3.7269
# [Epoch 70] Loss: 3.4810
# [Epoch 71] Loss: 3.5217
# [Epoch 72] Loss: 3.4326
# [Epoch 73] Loss: 3.6624
# [Epoch 74] Loss: 3.5613
# [Epoch 75] Loss: 3.5958
# [Epoch 76] Loss: 3.5146
# [Epoch 77] Loss: 3.4996
# [Epoch 78] Loss: 3.4605
# [Epoch 79] Loss: 3.4786
# [Epoch 80] Loss: 3.7462
# [Epoch 81] Loss: 3.4276
# [Epoch 82] Loss: 3.4979
# [Epoch 83] Loss: 3.4806
# [Epoch 84] Loss: 3.5999
# [Epoch 85] Loss: 3.8283
# [Epoch 86] Loss: 3.7114
# [Epoch 87] Loss: 3.6958
# [Epoch 88] Loss: 3.4271
# [Epoch 89] Loss: 3.6726
# [Epoch 90] Loss: 3.5850
# [Epoch 91] Loss: 3.6546
# [Epoch 92] Loss: 3.4840
# [Epoch 93] Loss: 3.4541
# [Epoch 94] Loss: 3.8285
# [Epoch 95] Loss: 3.6004
# [Epoch 96] Loss: 3.5572
# [Epoch 97] Loss: 3.7259
# [Epoch 98] Loss: 3.6888
# [Epoch 99] Loss: 3.4807
# [Epoch 100] Loss: 3.4763

# %% [markdown]
# Now plot your result below.

# %%
p = np.linspace(-0.5, 0.5, 500)
x_plot, y_plot = np.meshgrid(p, p)
X_plot = np.stack((x_plot, y_plot), axis=2).reshape(-1, 2)
X_plot = torch.from_numpy(X_plot).float()
output = net(X_plot)
output = output.detach().numpy()
output = output.reshape(x_plot.shape[0], x_plot.shape[1])

plt.contour(x_plot, y_plot, output, [0.5],
                  colors=('k',),
                  linewidths=(3,))
plot(X0, X1)

# %% [markdown]
# ### Implement your first multi-layer perceptron (MLP) for point cloud classification
# Now you should notice that your logistic regression model cannot classify the point cloud correctly, and this is as expected :)
# Therefore, we now ask you to implement an MLP for the same binary classification task.

# %%
# These are the parameters to be used
nInput = 2
nOutput = 1
nHidden = 16
act_fn = nn.ReLU()

class MLP(nn.Module):
    def __init__(self, nInput, nOutput, nHidden, act_fn):
        super().__init__()

        # Define the network layers in order.
        # Input is 2D (nInput).
        # Output is a single value (nOutput).
        # Multiple linear layers each followed by a ReLU non-linearity (apart from the last).
        #########################################################################
        # TODO: add a two-layer MLP, inside the `nn.Sequential` call.
        # Input is 2D.
        # Output is a single value.

        # Hint: unlike logistic regression where you need only one nn.Linear layer,
        # here you will have two nn.Linear layers. After the first layer, we
        # apply a ReLU activation function. The output is then passed to another
        # linear layer. Note that you should use `nHidden` below as the hidden dimension
        # of your linear layers.
        #########################################################################
        self.model = nn.Sequential(nn.Linear(nInput,nHidden), act_fn, nn.Linear(nHidden,nOutput))

    def forward(self, batch):
        # Process batch using the defined model.
        x = self.model(batch)
        # Final sigmoid activation to obtain a probability.
        return torch.sigmoid(x)

# %% [markdown]
# Run below again!

# %%
NUM_EPOCHS = 200

# create the network.
net = MLP(nInput, nOutput, nHidden, act_fn)

# create the optimizer.
optimizer = Adam(net.parameters(), lr=0.1)

best_accuracy = 0
for epoch_idx in range(NUM_EPOCHS):
    loss = train(net, optimizer, train_dataloader, epoch_idx)
    print('[Epoch %02d] Loss: %.4f' % (epoch_idx + 1, loss))
# Out:
# [Epoch 01] Loss: 6.5530
# [Epoch 02] Loss: 4.5854
# [Epoch 03] Loss: 3.8473
# [Epoch 04] Loss: 3.6831
# [Epoch 05] Loss: 4.0672
# [Epoch 06] Loss: 4.0625
# [Epoch 07] Loss: 3.9787
# [Epoch 08] Loss: 3.7177
# [Epoch 09] Loss: 3.7937
# [Epoch 10] Loss: 3.5548
# [Epoch 11] Loss: 3.8373
# [Epoch 12] Loss: 3.5788
# [Epoch 13] Loss: 3.9919
# [Epoch 14] Loss: 4.1118
# [Epoch 15] Loss: 3.0750
# [Epoch 16] Loss: 3.2109
# [Epoch 17] Loss: 3.4093
# [Epoch 18] Loss: 3.3483
# [Epoch 19] Loss: 3.4310
# [Epoch 20] Loss: 3.4103
# [Epoch 21] Loss: 3.1582
# [Epoch 22] Loss: 3.0734
# [Epoch 23] Loss: 3.2410
# [Epoch 24] Loss: 3.1691
# [Epoch 25] Loss: 3.8921
# [Epoch 26] Loss: 4.0657
# [Epoch 27] Loss: 3.6665
# [Epoch 28] Loss: 3.4042
# [Epoch 29] Loss: 3.5152
# [Epoch 30] Loss: 3.0495
# [Epoch 31] Loss: 3.0586
# [Epoch 32] Loss: 3.2403
# [Epoch 33] Loss: 3.3462
# [Epoch 34] Loss: 2.9839
# [Epoch 35] Loss: 3.1683
# [Epoch 36] Loss: 3.3443
# [Epoch 37] Loss: 3.1166
# [Epoch 38] Loss: 2.8976
# [Epoch 39] Loss: 3.0438
# [Epoch 40] Loss: 2.8975
# [Epoch 41] Loss: 3.1028
# [Epoch 42] Loss: 2.9491
# [Epoch 43] Loss: 2.9597
# [Epoch 44] Loss: 3.1678
# [Epoch 45] Loss: 3.0488
# [Epoch 46] Loss: 3.0674
# [Epoch 47] Loss: 2.9864
# [Epoch 48] Loss: 3.0852
# [Epoch 49] Loss: 3.1869
# [Epoch 50] Loss: 3.0162
# [Epoch 51] Loss: 3.1910
# [Epoch 52] Loss: 3.5760
# [Epoch 53] Loss: 3.0803
# [Epoch 54] Loss: 3.0306
# [Epoch 55] Loss: 3.0986
# [Epoch 56] Loss: 2.8001
# [Epoch 57] Loss: 2.9853
# [Epoch 58] Loss: 2.8413
# [Epoch 59] Loss: 2.7045
# [Epoch 60] Loss: 2.6956
# [Epoch 61] Loss: 2.4259
# [Epoch 62] Loss: 2.2413
# [Epoch 63] Loss: 2.0374
# [Epoch 64] Loss: 2.0060
# [Epoch 65] Loss: 1.5596
# [Epoch 66] Loss: 1.4387
# [Epoch 67] Loss: 1.2970
# [Epoch 68] Loss: 1.0036
# [Epoch 69] Loss: 0.7455
# [Epoch 70] Loss: 0.8075
# [Epoch 71] Loss: 1.0180
# [Epoch 72] Loss: 0.7743
# [Epoch 73] Loss: 0.6511
# [Epoch 74] Loss: 0.4193
# [Epoch 75] Loss: 0.4225
# [Epoch 76] Loss: 0.4382
# [Epoch 77] Loss: 0.3872
# [Epoch 78] Loss: 0.2802
# [Epoch 79] Loss: 0.3429
# [Epoch 80] Loss: 0.2779
# [Epoch 81] Loss: 0.2304
# [Epoch 82] Loss: 0.3524
# [Epoch 83] Loss: 0.2379
# [Epoch 84] Loss: 0.2485
# [Epoch 85] Loss: 0.3281
# [Epoch 86] Loss: 0.1739
# [Epoch 87] Loss: 0.1496
# [Epoch 88] Loss: 0.1275
# [Epoch 89] Loss: 0.1130
# [Epoch 90] Loss: 0.1119
# [Epoch 91] Loss: 0.0949
# [Epoch 92] Loss: 0.1026
# [Epoch 93] Loss: 0.0981
# [Epoch 94] Loss: 0.0811
# [Epoch 95] Loss: 0.0911
# [Epoch 96] Loss: 0.0772
# [Epoch 97] Loss: 0.0730
# [Epoch 98] Loss: 0.0712
# [Epoch 99] Loss: 0.0702
# [Epoch 100] Loss: 0.0722
# [Epoch 101] Loss: 0.0624
# [Epoch 102] Loss: 0.0651
# [Epoch 103] Loss: 0.0589
# [Epoch 104] Loss: 0.0552
# [Epoch 105] Loss: 0.0628
# [Epoch 106] Loss: 0.0720
# [Epoch 107] Loss: 0.0520
# [Epoch 108] Loss: 0.0583
# [Epoch 109] Loss: 0.0635
# [Epoch 110] Loss: 0.0515
# [Epoch 111] Loss: 0.0439
# [Epoch 112] Loss: 0.0465
# [Epoch 113] Loss: 0.0460
# [Epoch 114] Loss: 0.0443
# [Epoch 115] Loss: 0.0402
# [Epoch 116] Loss: 0.0418
# [Epoch 117] Loss: 0.0404
# [Epoch 118] Loss: 0.0384
# [Epoch 119] Loss: 0.0415
# [Epoch 120] Loss: 0.0372
# [Epoch 121] Loss: 0.0450
# [Epoch 122] Loss: 0.0397
# [Epoch 123] Loss: 0.0322
# [Epoch 124] Loss: 0.0323
# [Epoch 125] Loss: 0.0364
# [Epoch 126] Loss: 0.0323
# [Epoch 127] Loss: 0.0355
# [Epoch 128] Loss: 0.0405
# [Epoch 129] Loss: 0.0291
# [Epoch 130] Loss: 0.0273
# [Epoch 131] Loss: 0.0293
# [Epoch 132] Loss: 0.0465
# [Epoch 133] Loss: 0.0230
# [Epoch 134] Loss: 0.0628
# [Epoch 135] Loss: 0.2017
# [Epoch 136] Loss: 0.3618
# [Epoch 137] Loss: 0.0472
# [Epoch 138] Loss: 0.0258
# [Epoch 139] Loss: 0.0395
# [Epoch 140] Loss: 0.0260
# [Epoch 141] Loss: 0.0251
# [Epoch 142] Loss: 0.0226
# [Epoch 143] Loss: 0.0224
# [Epoch 144] Loss: 0.0221
# [Epoch 145] Loss: 0.0219
# [Epoch 146] Loss: 0.0201
# [Epoch 147] Loss: 0.0199
# [Epoch 148] Loss: 0.0190
# [Epoch 149] Loss: 0.0178
# [Epoch 150] Loss: 0.0195
# [Epoch 151] Loss: 0.0207
# [Epoch 152] Loss: 0.0166
# [Epoch 153] Loss: 0.0175
# [Epoch 154] Loss: 0.0168
# [Epoch 155] Loss: 0.0167
# [Epoch 156] Loss: 0.0159
# [Epoch 157] Loss: 0.0155
# [Epoch 158] Loss: 0.0156
# [Epoch 159] Loss: 0.0147
# [Epoch 160] Loss: 0.0156
# [Epoch 161] Loss: 0.0142
# [Epoch 162] Loss: 0.0166
# [Epoch 163] Loss: 0.0141
# [Epoch 164] Loss: 0.0140
# [Epoch 165] Loss: 0.0132
# [Epoch 166] Loss: 0.0132
# [Epoch 167] Loss: 0.0140
# [Epoch 168] Loss: 0.0132
# [Epoch 169] Loss: 0.0132
# [Epoch 170] Loss: 0.0150
# [Epoch 171] Loss: 0.0146
# [Epoch 172] Loss: 0.0127
# [Epoch 173] Loss: 0.0124
# [Epoch 174] Loss: 0.0115
# [Epoch 175] Loss: 0.0132
# [Epoch 176] Loss: 0.0118
# [Epoch 177] Loss: 0.0122
# [Epoch 178] Loss: 0.0112
# [Epoch 179] Loss: 0.0109
# [Epoch 180] Loss: 0.0115
# [Epoch 181] Loss: 0.0114
# [Epoch 182] Loss: 0.0130
# [Epoch 183] Loss: 0.0101
# [Epoch 184] Loss: 0.0103
# [Epoch 185] Loss: 0.0101
# [Epoch 186] Loss: 0.0097
# [Epoch 187] Loss: 0.0099
# [Epoch 188] Loss: 0.0094
# [Epoch 189] Loss: 0.0095
# [Epoch 190] Loss: 0.0094
# [Epoch 191] Loss: 0.0091
# [Epoch 192] Loss: 0.0094
# [Epoch 193] Loss: 0.0097
# [Epoch 194] Loss: 0.0100
# [Epoch 195] Loss: 0.0086
# [Epoch 196] Loss: 0.0094
# [Epoch 197] Loss: 0.0096
# [Epoch 198] Loss: 0.0090
# [Epoch 199] Loss: 0.0088
# [Epoch 200] Loss: 0.0081

# %% [markdown]
# Again plot your result. You should see that the decision boundary can clearly separate the point clouds.

# %%
p = np.linspace(-0.5, 0.5, 500)
x_plot, y_plot = np.meshgrid(p, p)
X_plot = np.stack((x_plot, y_plot), axis=2).reshape(-1, 2)
X_plot = torch.from_numpy(X_plot).float()
output = net(X_plot)
output = output.detach().numpy()
output = output.reshape(x_plot.shape[0], x_plot.shape[1])

plt.contour(x_plot, y_plot, output, [0.5],
                  colors=('k',),
                  linewidths=(3,))
plot(X0, X1)

# %% [markdown]
# When you are done, move forward to `image_classification.ipynb`.
